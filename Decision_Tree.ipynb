# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunkrishna1412/Algo-Trail/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/cleaned_data.csv')

# %%
data
# Out:
#    Unnamed: 0  temp in c  sales
# 0         0.0       20.0   13.0
# 1         1.0       25.0   21.0
# 2         2.0       30.0   25.0
# 3         3.0       35.0   35.0
# 4         4.0       40.0   38.0

# %%
x = data.drop('sales', axis=1)
y = data['sales']

# %% [markdown]
# Split the dataset into training and testing sets

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
dt = DecisionTreeClassifier(max_depth=3, random_state=0)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred = dt.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc *100:.2f}%")
# Out:
# Accuracy: 0.00%

# %%
plt.figure(figsize=(12,8))
plot_tree(dt, feature_names=feature_names, class_names=data.target_names, filled=True, rounded=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-1c13bab4a761> in <cell line: 2>()
#       1 plt.figure(figsize=(12,8))
# ----> 2 plot_tree(dt, feature_names=feature_names, class_names=data.target_names, filled=True, rounded=True)
#       3 plt.show()
#
# NameError: name 'feature_names' is not defined

# %%
plt.figure(figsize=(12,8))
# Get feature names from the DataFrame's columns (excluding the target column)
feature_names = x.columns
plot_tree(dt, feature_names=feature_names, class_names=data['sales'].unique().astype(str), filled=True, rounded=True)
plt.show()
