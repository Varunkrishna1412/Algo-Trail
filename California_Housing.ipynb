# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunkrishna1412/Algo-Trail/blob/main/California_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
from sklearn.model_selection import train_test_split

x= data.drop  (['median_house_value'], axis=1)
y= data['median_house_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924569           -0.108191     0.049132
# latitude            -0.924569  1.000000            0.010003    -0.039895
# housing_median_age  -0.108191  0.010003            1.000000    -0.357665
# total_rooms          0.049132 -0.039895           -0.357665     1.000000
# total_bedrooms       0.074320 -0.071105           -0.316545     0.929312
# population           0.102228 -0.112087           -0.292215     0.855383
# households           0.059228 -0.074833           -0.298598     0.917995
# median_income       -0.012218 -0.082005           -0.122524     0.198958
# median_house_value  -0.037965 -0.150773            0.105855     0.137731
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.074320    0.102228    0.059228      -0.012218
# latitude                 -0.071105   -0.112087   -0.074833      -0.082005
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households'])+1

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7326
# INLAND        5251
# NEAR OCEAN    2082
# NEAR BAY      1848
# ISLAND           5
# Name: count, dtype: int64

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14804    -117.17     32.63                26.0     7.388946        5.634790
# 18708    -122.41     40.58                35.0     7.636752        5.955837
# 16586    -121.44     37.75                16.0     7.709757        6.129050
# 5472     -118.45     33.99                52.0     6.918695        5.501258
# 19011    -122.00     38.35                24.0     6.614726        4.762174
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0     8.804775        7.116394
# 14204    -117.06     32.69                 9.0     7.327123        5.598422
# 4137     -118.18     34.12                45.0     7.782390        6.192362
# 11032    -117.84     33.78                24.0     8.247482        6.669498
# 4067     -118.47     34.15                43.0     6.690842        4.770685
#
# ...

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 14804      False   False   False     False        True
# 18708      False    True   False     False       False
# 16586      False    True   False     False       False
# 5472        True   False   False     False       False
# 19011      False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 15174       True   False   False     False       False
# 14204      False   False   False     False        True
# 4137        True   False   False     False       False
# 11032       True   False   False     False       False
# 4067        True   False   False     False       False
#
# [16512 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14804    -117.17     32.63                26.0     7.388946        5.634790
# 18708    -122.41     40.58                35.0     7.636752        5.955837
# 16586    -121.44     37.75                16.0     7.709757        6.129050
# 5472     -118.45     33.99                52.0     6.918695        5.501258
# 19011    -122.00     38.35                24.0     6.614726        4.762174
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0     8.804775        7.116394
# 14204    -117.06     32.69                 9.0     7.327123        5.598422
# 4137     -118.18     34.12                45.0     7.782390        6.192362
# 11032    -117.84     33.78                24.0     8.247482        6.669498
# 4067     -118.47     34.15                43.0     6.690842        4.770685
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=train_data, x='longitude', y='latitude', hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=train_data, x='longitude', y='latitude', hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['households_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
print(data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=train_data, x='longitude', y='latitude', hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
test_data = x_test.join(y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households'])+1
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_rooms'] = test_data['total_rooms'] / test_data['households']
test_data = pd.get_dummies(test_data, columns=['ocean_proximity'], prefix=['ocean_proximity'], drop_first=False)

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
for column in train_data.columns:
    if column.startswith('ocean_proximity_'):
        train_data[column] = train_data[column].astype(int)

for column in test_data.columns:
    if column.startswith('ocean_proximity_'):
        test_data[column] = test_data[column].astype(int)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15462    -117.22     33.17                 6.0     2.116880        0.703158
# 6976     -118.04     33.99                47.0     2.178876        0.715910
# 20247    -119.26     34.27                42.0     2.057105        0.684358
# 19068    -122.47     38.29                14.0     2.221914        0.726346
# 5603     -118.28     33.79                36.0     2.151284        0.710073
# ...          ...       ...                 ...          ...             ...
# 3875     -118.54     34.19                33.0     2.163201        0.709759
# 1019     -121.78     37.67                28.0     2.137827        0.694873
# 15909    -122.42     37.74                52.0     2.131034        0.701781
# 12318    -116.39     33.82                15.0     2.333710        0.748198
# 13852    -117.28     34.51                10.0     2.246058        0.727425
#
# ...

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10178    -117.96     33.86                35.0     7.671827        6.066108
# 17567    -121.91     37.31                16.0     7.993958        6.801283
# 18885    -122.23     38.10                46.0     8.329417        6.797940
# 20006    -119.08     36.13                21.0     7.728416        5.932245
# 5096     -118.30     33.97                42.0     6.851185        5.303305
# ...          ...       ...                 ...          ...             ...
# 18548    -122.02     36.97                39.0     7.661527        6.495266
# 3910     -118.53     34.20                26.0     7.706163        6.496775
# 7052     -118.05     33.92                33.0     7.600902        6.154858
# 4581     -118.28     34.06                17.0     7.831617        7.087574
# 16600    -120.69     35.65                14.0     8.157084        6.791221
#
# ...

# %%
reg.predict(x_test)
# Out:
# array([201882.95986765, 147279.68214384, 207796.60979847, ...,
#        110229.93045317, 137315.7328207 , 169083.81714046])
